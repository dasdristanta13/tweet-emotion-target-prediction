# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from EDA import *

# %%
df = pd.read_excel('NLP Engineer Assignment Dataset (1) (1) (1) (1).xlsx', sheet_name='Train')
df.columns = ['text', 'target', 'emotion']

# %%
basic_overview(df)
# Out:
# Dataset Shape: (8589, 3)
#
# Column Data Types:
#  text       object
# target     object
# emotion    object
# dtype: object
#
# Missing Values:
#  text          1
# target     5298
# emotion       0
# dtype: int64

# %%
text_length_analysis(df, 'text')

# %%
target_distribution(df, 'target')
# Out:
# Target Value Counts:
#  target
# iPad                               946
# Apple                              661
# iPad or iPhone App                 470
# Google                             430
# iPhone                             297
# Other Google product or service    293
# Android App                         81
# Android                             78
# Other Apple product or service      35
# Name: count, dtype: int64

# %%
target_distribution(df, 'emotion')
# Out:
# Target Value Counts:
#  emotion
# No emotion toward brand or product    5389
# Positive emotion                      2672
# Negative emotion                       519
# I can't tell                             9
# Name: count, dtype: int64

# %%
word_frequency(df, 'text')
# Out:
# Most Common Words:
#  [('@mention', 6337), ('{link}', 4066), ('#sxsw', 3789), ('the', 3690), ('#SXSW', 3437), ('to', 3312), ('RT', 2738), ('at', 2692), ('for', 2308), ('a', 2034), ('in', 1677), ('of', 1581), ('iPad', 1578), ('Google', 1514), ('is', 1487), ('and', 1436), ('Apple', 1373), ('on', 1162), ('I', 940), ('store', 861)]
